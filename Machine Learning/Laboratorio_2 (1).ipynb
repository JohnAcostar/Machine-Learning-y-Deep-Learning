# %% [markdown]
# # **Laboratorio 2: Una introducción a Matplotlib**
# **Facultad de ingeniería**
#
# Departamento de Ingeniería Biomédica
#
# Universidad de los Andes
#
# **IBIO-2340** Fundamentos del Machine Learning

# %% [markdown]
# **Nombres de los integrantes**
#
#
# 1.   John Anderson Acosta Ramirez
# 2.
#
# **Número del grupo**
#
# Grupo 2

# %% [markdown]
# # **1. Gráficos simples**
#
# Para comenzar la introducción a la librería *Matplotlib*, deben graficar curvas simples y conjuntos de datos en un solo gráfico con los respectivos nombres de los ejes, título, leyendas y escalas. En general, para este punto, deben importar *pyplot*, de la siguiente forma:
#
#
#
# ```
# import matplotlib.pyplot as plt
# ```

# %% [markdown]
# **1.1. Para ejemplificar la forma de realizar gráficos simples, se grafican las funciones $sin(t)$ y $cos(t)$, donde $t$ es el tiempo. Para esto, se crea primero un arreglo con que contenga los datos de tiempo**

# %%
import numpy as np

t = np.linspace(0,10,100)

# %% [markdown]
# Luego, se usa la librería *Numpy* para obtener los datos en la imágen de las funciones mencionadas

# %%
s = np.sin(t)
c = np.cos(t)

# %% [markdown]
# Ahora, se debe conocer la función *subplots()*, la cual permite retornar los atributos *fig* y *ax* con diversos parámetros para poder configurar el gráfico. Algunos parámetros de esta función son:
#
# - *nrows*, *ncols*: Número de filas y columnas en una cuadrícula de subplots (Valor 1 por defecto)
# - *sharex, sharey*: Permite compartir eje *x* y eje *y* (Valor por defecto 'False')
# - *figsisze*: Permite establecer un tamaño del gráfico. *figsize = (Height, width)*
# - *layout* = Ajusta la cuadrícula para evitar que se sobrelapen los sublots. *layout = 'constrained'*
#
# La forma de usar esta función es:
#
# ```
# fig, ax = plt.subplots(nrows, ncols, sharex = False/True, sharey = False/True, figsize = (height, width))
# ```

# %% [markdown]
# Debido a que solo hay un subplot, el atributo *ax* solo tiene un elemento que corresponde a dicho subplot. Luego, para graficar lo anterior, a este atributo, es posible aplicarle algunas funciones para graficar. Algunas de ellas son:
#
#
# - *ax.plot(x,y,label = 'leyenda para la curva', linewidth = Grosor de curva)* : Grafica el conjunto de datos *y* contra el conjunto *x*
# - *ax.set(xlabel = 'Título del eje x', ylabel = 'Título del eje y', title = 'Título del subplot')*: Asigna títulos a los ejes y al subplot
# - *ax.legend(loc = 'Ubicación de la leyenda')*: Muestra la leyenda de las curvas graficadas, la ubicaciones pueden ser: *'right', 'left', 'center', 'upper right', 'upper left', 'lower right', 'lower left', 'center right', 'center left', 'upper center, 'lower center'*
# - *ax.grid()*: Muestra una cuadrícula.
# - *ax.set_xlim([mínimo, máximo])*: Establece límites para el eje $x$.
# - *ax.set_ylim([mínimo, máximo])*: Establece límites para el eje $y$.
#
# Cabe resaltar que hay otras formas de configurar el gráfico para llegar al mismo resultado, depende del estilo de cada programador.
#
# Luego, para darle un título general al gráfico, se hace de la forma:
#
# ```
# fig.suptitle('Título general del gráfico')
# ```
# Finalmente, para mostrar el gráfico, se escribe:
#
# ```
# plt.show()
# ```
# A continuación, se muestra el ejemplo anterior:

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(t,s,label='Función seno')
ax.plot(t,c,label='Función coseno')
ax.set(xlabel = 'Tiempo [s]', ylabel='Funciones', title = 'Seno vs Coseno')
ax.legend(loc='lower right')
fig.suptitle('Gráfico simple')
plt.show()

# %% [markdown]
# Si se quisera presentar las curvas en dos subplots diferentes, hay que tener en cuenta que al cambiar el número de filas y/o columnas, el atributo *ax* cambia su tamaño para ser un arreglo. Por ejemplo, si se quisiera presentar un gráfico de dos filas y dos columnas, la forma sería:
#
# ```
# fig, ax = plt.subplots(2, 2)
# ```
#
# Donde *ax* ahora es un arreglo de tamaño $2 \times 2$, luego, si se quiere llamar algún subplot en específico, por ejemplo, el que se encuentra en la posición $(2,1)$, se hace de la forma:
#
# ```
# ax[1,0]
# ```

# %% [markdown]
# A continuación, se muestra la forma en la que se presentarían las curvas anteriroes en dos subplots:

# %%
fig, ax = plt.subplots(2,1,layout='constrained')
ax[0].plot(t,s,label='Función seno')
ax[1].plot(t,c,label='Función coseno')
ax[0].set(xlabel = 'Tiempo [s]', ylabel='Funciones', title = 'Seno')
ax[1].set(xlabel = 'Tiempo [s]', ylabel='Funciones', title = 'Coseno')
fig.suptitle('Gráfico simple')
plt.show()

# %% [markdown]
# Es necesario aclarar que hay diferentes formas de graficar un conjunto de datos. Para esto, se remplaza la función *plot* por otras como:
#
# - *scatter*: Grafica los conjuntos de datos como puntos.
# - *bar*: Grafica los conjuntos como barras.
# - *errorbar*: Incluye barras de error para datos estadísticos.
# - *fill_between*: Sobrea áreas de confianza.
# - *hist*: Muestra un histograma de los datos.
#
# La documentación de estas funciones se encuentra en el siguiente link: [Documentación](https://matplotlib.org/stable/gallery/index.html)
#
#
# **1.2. Ejercicios**
#
# A continuación, deben resolver los siguientes ejercicios realizando lo que se les pide.
#
# **1.2.1.** Grafique las siguientes funciones en cuatro subplots, incluya labels, títulos en subplots y título para la figura:
#
# - $f(x) = \ln(x) $, (Título: Logarítmica)
# - $g(x) = e^x$, (Título: Exponencial)
# - $f(x) + g(x)$, (Título: Suma)
# - $f(g(x))$, (Título: Compuesta)
#
# Donde $x$ está en segundos y $f(x), g(x)$ están en metros.

# %%
import numpy as np
import matplotlib.pyplot as plt

#x = segundos
x = np.linspace(0,20,1000)
loga=np.log(x)

expo=np.exp(x)


suma =loga+expo


comp=np.log(np.exp(x))

fig, ax = plt.subplots(2,2,layout='constrained')
ax[0,0].plot(x,loga,label='Logarítmica')
ax[0,1].plot(x,expo,label='Exponencial',color="orange")
ax[1,0].plot(x,suma,label='Suma',color="pink")
ax[1,1].plot(x,comp,label='Compuesta',color="green")

ax[0,0].set(xlabel = 'Tiempo [s]', ylabel='Longitud [M]', title = 'Logarítmica')
ax[0,1].set(xlabel = 'Tiempo [s]', ylabel='Longitud [M]', title = 'Exponencial')
ax[1,0].set(xlabel = 'Tiempo [s]', ylabel='Longitud [M]', title = 'Suma')
ax[1,1].set(xlabel = 'Tiempo [s]', ylabel='Longitud [M]', title = 'Compuesta')

fig.suptitle('Gráfica de funciones e^x y log(x) ')
fig.tight_layout()
plt.show()
# Out:
# <ipython-input-1-12616e018f8f>:6: RuntimeWarning: divide by zero encountered in log
#   loga=np.log(x)
# <ipython-input-1-12616e018f8f>:28: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()

# %% [markdown]
# **1.2.2.** Grafique las mismas funciones anterioes pero esta vez sobre un mismo subplot, ahora incluyendo la leyenda ubicada en la parte inferior izquierda. El grosor de las curvas ahora debe ser de 2.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,20,100)
loga=np.log(x)
expo=np.exp(x)
suma =loga+expo
comp=np.log(np.exp(x))

fig, ax = plt.subplots()
ax.plot(x,loga,label='logarítmica', linewidth=2, color="pink")
ax.plot(x,expo,label='exponencial', linewidth=2, color="orange")
ax.plot(x,suma,label='suma', linewidth=2, color="green")
ax.plot(x,comp,label='compuesta', linewidth=2, color="red")
ax.set(xlabel = 'Tiempo [s]', ylabel='Longitud [m]', title = "Logarítmica vs Exponencial vs Suma vs Compuesta")
ax.legend(loc="lower left")
fig.suptitle('Gráfica de funciones')
plt.show()
# Out:
# <ipython-input-2-c8a5758994e6>:5: RuntimeWarning: divide by zero encountered in log
#   loga=np.log(x)

# %% [markdown]
# **1.2.3.** Suponga que hizo una regresión lineal de la posición en el tiempo de un atelta, donde obtuvo la siguiente ecuación:
#
# \begin{align*}
#   y = 3x - 1
# \end{align*}
#
# También sabe que el error de todos los datos es de $0.3$. Grafique 10 puntos de forma *scatter* donde incluya barras de error en cada punto. Además, el eje horizontal debe estar entre $5$ y $10$.

# %%
import matplotlib.pyplot as plt
import numpy as np


tiempo =np.linspace(5,10,10)
Posicion =3*tiempo -1

plt.errorbar(tiempo,Posicion,0.3,fmt="o", color ="plum")
plt.title("Regresión lineal posición contra tiempo de un atleta", color ="red")
plt.xlabel("Tiempo [s]", color ="red")
plt.ylabel("Posición [M]", color ="red")
plt.show()

# %% [markdown]
# **1.2.4.** Suponga que la regresión anterior no fue suficiente y necesita también graficar la regresión de la frecuencia cardiaca, que sigue la siguiente relación:
#
# \begin{align*}
#   y = 70 + 2\sqrt{10x}
# \end{align*}
#
# Grafique sobre el mismo subplot pero agregue un eje vertical a la derecha correspondiente a la frecuencia cardiaca en uniades de $\frac{beat}{min}$. Incluya leyendas. El eje asociado a la posición debe ir desde 70 hasta 115.

# %%
import matplotlib.pyplot as plt
import numpy as np

tiempo=np.linspace(5,10,10)

ecuacion=3*tiempo-1


regresion = 70+(2*np.sqrt(10*tiempo))


fig, ax1 = plt.subplots()
ax1.set_xlabel("Tiempo [s]", color ="firebrick")
ax1.set_ylabel("Posición [m]", color ="firebrick")


ax1.errorbar(tiempo, ecuacion, 0.3, fmt="o", label="Regresion lineal de posición",color ="plum")


ax2 = ax1.twinx()
ax2.set_ylabel("Frecuencia Cardíaca [beat/min]", color ="firebrick")
ax2.set_ylim(70, 115)
ax2.plot(tiempo, regresion, color="lightcoral", label="Regresión Lineal de la frecuencia cardíaca")

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines = lines1 + lines2
labels = labels1 + labels2
ax1.legend(lines, labels, loc="upper left")

plt.title("Regresión lineal de la frecuencia cardiaca, posición de un atleta vs. tiempo", color ="firebrick")
plt.show()

# %% [markdown]
# *1.2.5* Cree 1000 datos aleatorios con distribución uniforme y otros 1000 con distrbución normal y súmelos de la siguiente forma:
#
#
#
# ```
# uniform_Set = np.random.uniform(size = 1000)
# normal_Set = np.random.normal(size = 1000)
# sum = np.add(Uniform_Set, Normal_Set)
#
# ```
#
# Grafique el correspondiente histograma para 10, 20, 30 y 50 particiones (bins), cada una en un subplot diferente. Agregue título al gráfico, a los subplots, y a los ejes (invente el título para estos).

# %%
import matplotlib.pyplot as plt
import numpy as np

uniform_Set = np.random.uniform(size = 1000)
normal_Set = np.random.normal(size = 1000)
sum = np.add(uniform_Set, normal_Set)

fig, ax = plt.subplots(2,2, figsize=(10,10))
valores=[10,20,30,50]

for i in range(len(valores)):
  plt.subplot(2,2,i+1)
  bins=valores[i]
  plt.xlabel("Suma de Datos")
  plt.ylabel("Frecuencia")
  plt.hist(sum, bins=bins, color="gold")
  plt.title(f"Histograma ({bins} bins)", color ="firebrick")


fig.suptitle("Histogramas de 10,20,30,40", fontsize=16, color="firebrick")
fig.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# # **2. Superficies y curvas de nivel**
#
# Durante el curso se tratarán temas de optimización donde será necesario el manejo de funciones multivariable. Muchos procesos optimización requieren un análisis gráficos para facilitar el entendimiento y verificar las soluciones. Entre estos análisis, están las superficies y curvas de nivel, las cuales son fundamentales para el curso. Para comenzar, es necesario comprender que estas funciones deben mapear desde $\mathbb{R^n}$ hasta $\mathbb{R}$. Es decir, deben tomar un vector de variables $[x_1, x_2, ..., x_n]^T$ y transformarlo en un escalar a través de operaciones matemáticas. Estas funciones de definen como:
#
# \begin{align*}
# f: \mathbb{R^n}  \rightarrow \mathbb{R}.
# \end{align*}
#
# Hace falta aclarar que para poder graficar una superficie, la función debe mapear desde $\mathbb{R^2}$ hasta $\mathbb{R}$, porque, de lo contrario, si $n>2$, no hay forma de graficar la función.
#
# **2.1. Superficies**
#
#  Para comenzar, se mostrará el proceso para graficar una superficie y los posibles ajustes y variantes que hay para esto. En principio, es necesario crear una función, en este caso, como ejemplo, se usará un paraboloide definido como:
#
# \begin{align*}
# f(x_1,x_2) = x_1^2 + x_2^2
# \end{align*}
#
# El proceso es similar a un gráfico simple, pero con algunos parámetros adicionales. Primero, veremos cómo cambia la función *subplots*, a la cual se le debe adicional el parámetro:
#
# ```
# fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
# ```
#
# Lo que indica que se trata de una superficie. Ahora, se definen las variables como arreglos, igual que en el gráfico simple:
#
#
#
# ```
# x_1 = np.linspace(-5,5,100)
# x_2 = np.linspace(-5,5,100)
# ```
#
# El principal cambio es que la función no se puede definir con los arreglos creados anteriormente, debido a que es necesario crear una cuadrícula de puntos que serán proyectados en un eje vertical. La forma de hacer esto es la siguiente:
#
# ```
# (X_1, X_2) = np.meshgrid(x_1, x_2)
# ```
#
# Ahora si es posible definir la función:
#
# ```
# f = X_1**2 + X_2**2
# ```
#
# Ahora, para graficar la superficie se usa la función *plot_surface*, la cual recibe como parámetros las variables independientes en forma de cuadrícula y la función dependiente.
#
# ```
# surf = ax.plot_surface(X_1, X_2, f)
# ```
#
# Sin embargo, esta puede recibir más parámetros para poder ajustar el gráfico. Algunos de ellos son:
#
# - *rcount, ccount:* Indica la cantidad de muestras que toma de cada variable independiente. El valor por defecto es 50,
# - *cmap:* Agrega efectos de color (Leer documentación para ver las opciones)
# - *facecolors:* Colorea un solo cuadrante de la cuadrícula.
# - *shade:* Agrega sombra. (True por defecto).
#
# Finalmente, es posible que el título del eje vertical no sea visible. Para solucionar eso, se incluye el siguiente comando:
#
# ```
# ax.set_box_aspect(aspect=None, zoom=0.8)
# ```
# Y luego se ajusta el tamaño de la figura.
#
# El resultado del ejemplo sería el siguiente:

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"} ,  figsize = (5, 5))
x_1 = np.linspace(-5,5,100)
x_2 = np.linspace(-5,5,100)
(X_1, X_2) = np.meshgrid(x_1, x_2)
f = X_1**2 + X_2**2

surf = ax.plot_surface(X_1, X_2, f)
ax.set_xlabel("X label")
ax.set_ylabel("Y label")
ax.set_zlabel("Z label")
ax.set_box_aspect(aspect=None, zoom=0.8)
ax.set(title = 'Paraboloide')

plt.show()

# %% [markdown]
# Igual que en los gráficos simples, existen variantes para graficar una superficie. La forma de incluirlas, es cambiando la función *plot_surface* por alguna de estas:
#
# - *scatter:* Grafica los datos como puntos.
# - *bar3d:* Grafica los datos en barras.
# - *wireframe:* Cambia la superficie por un alambrado.
# - *trisufr*: Modifica la cuadrícula por triángulos.
# - *errorbar*: Añade barras de error en los puntos.
#
#
# **2.2. Curvas de nivel**
#
# En ocasiones, en anlálisis gráfico no es suficiente a través de la representación de la función como una superficie. En vez de esto, es resulta más conveniente representarla mediante curvas de nivel. Las curvas de nivel son el resultado de proyectar en un plano bidimensional un corte vertical del sólido generado por función, como se muestra en la siguiente imágen:
#
# ![image.png](data:image/png;base64,...)
#
# Note que, en el caso de un paraboloide,  el corte transversal a lo largo del eje vertical genera una circunferencia. En esencia, hay dos formas de representar estas curvas: a través de la curva generada, o mediante un mapa de calor. La forma de hacerlo es mediante las funciones *contour* y *contourf*, respectivamente, y su sintaxis es:
#
# ```
# CS = ax.contour(X_1, X_2, f)
# CS = ax.contourf(X_1, X_2, f)
# ```
#
# Igual que todas las funciones anteriores, estas también se pueden ajustar mediante parámetros. Algunos de ellos son:
#
# Para ambas funciones:
#
# - *levels*: Indica el número de cortonos que se grafica.
# - *alpha*: Indica la transparencia de los colores. (*aplpha* = 0: invisible, *alpha = 1: visible)
# - *colors*: Indica el color de las curvas.
# - *cmap*: Cambia el tipo de efecto de color.
#
# Adicionalmente, cuando se trabaja con curvas de nivel, es posible usar otras funciones útiles como *clabel*, la cual permite agregar títulos a las curvas similar a una leyenda. La forma de usarla es la siguiente:
#
# ```
# ax.clabel(CS)
# ```
#
# Donde algunos argumentos de la función son:
#
# - *fontsize*: Ajusta el tamaño de la letra.
# - *colors*: Especifica el color de la letra.
# - *rightside_up*: Cambia la orientación del texto de forma radial (True por defecto)
#
# Finalmente, para el caso de la función *contourf*, es conveniente agregar una barra de color que indique cuantitativamente el rango de los colores. La forma de hacerlo es:
#
# ```
# fig.colorbar(CS)
# ```
#
# Usando el ejemplo del paraboloide, quedaría así:

# %%
fig, ax = plt.subplots()
x_1 = np.linspace(-5,5,100)
x_2 = np.linspace(-5,5,100)
(X_1, X_2) = np.meshgrid(x_1, x_2)
f = X_1**2 + X_2**2

CS1 = ax.contour(X_1, X_2, f, alpha = 0.5)
ax.clabel(CS1, rightside_up = False)
ax.set_xlabel("X label")
ax.set_ylabel("Y label")
ax.set(title = 'Contour')
plt.show()


fig, ax = plt.subplots()
CS2 = ax.contourf(X_1, X_2, f, levels = 10)
ax.set_xlabel("X label")
ax.set_ylabel("Y label")
ax.set(title = 'Contourf')
fig.colorbar(CS2)
plt.show()

# %% [markdown]
# **2.3. Ejercicios**
#
# A continuación, deben resolver los siguientes ejercicios realizando lo que se les pide. Las funciones a continuación son formas cuadráticas, que serán útiles en algunos métodos de optimización.
#
# **2.3.1.** Grafique una superficie para las siguientes funciones cuadráticas en cuatro subplots en una misma figura (recuerde añadir labels para los tres ejes, títulos a los subplots y título general):
#
# - $f_1(x_1, x_2) = x_1^2 - x_2^2$, (surface, agregue coloreado tipo *coolwarm*)
# - $f_2(x_1, x_2) = - x_1^2 + x_2^2$, (scatter)
# - $f_3(x_1, x_2) = x_1^2 + x_2^2 + x_1x_2$, (wireframe)
# - $f_4(x_1, x_2) = x_1^2 + x_2^2 - x_1x_2$, (trisurf)
#
# Donde $x_1 \in [-10,10], x_2 \in [-10,10]$

# %%
import matplotlib.pyplot as plt
import numpy as np


x_1 = np.linspace(-10,10,100)
x_2 = np.linspace(-10,10,100)
(X_1, X_2) = np.meshgrid(x_1, x_2)
f = X_1**2 - X_2**2
g = - X_1**2 + X_2**2
h =  X_1**2 + X_2**2 + X_1*X_2
i =   X_1**2 + X_2**2 - X_1*X_2

fig, ax = plt.subplots(2,2,subplot_kw={"projection": "3d"}, figsize=(15, 15))

fig.suptitle("Funciones cuadráticas", fontsize=16)



surf = ax[0,0].plot_surface(X_1, X_2, f,cmap="coolwarm")
ax[0,0].set_title("Superficie de f1(x1,x2)= x1^2 - x2^2")
ax[0,0].set_xlabel("X label")
ax[0,0].set_ylabel("Y label")
ax[0,0].set_zlabel("Z label")

ax[0,1].scatter(X_1, X_2, g)
ax[0,1].set_title("Superficie de f2(x1,x2)= -x1^2 +x2^2")
ax[0,1].set_xlabel("X label")
ax[0,1].set_ylabel("Y label")
ax[0,1].set_zlabel("Z label")

ax[1,0].plot_wireframe(X_1, X_2, h)
ax[1,0].set_title("Superficie de f3(x1,x2)= x1^2 + x2^2+ x1x2")
ax[1,0].set_xlabel("X label")
ax[1,0].set_ylabel("Y label")
ax[1,0].set_zlabel("Z label")

ax[1,1].plot_trisurf(X_1.flatten(), X_2.flatten(), i.flatten(), cmap='viridis')
ax[1,1].set_title("Superficie de f4(x1,x2)= x1^2 + x2^2 - x1x2")
ax[1,1].set_xlabel("X label")
ax[1,1].set_ylabel("Y label")
ax[1,1].set_zlabel("Z label")

plt.show()

# %% [markdown]
# **2.3.2** Grafique en cuatro subplots en una misma figura las curvas de nivel con los respectivos labels para los ejes y las curvas, títulos y título general. Deben tener 6 niveles con una transparencia de 0.7. El label de las curvas de nivel debe ser de color negro.

# %%
import matplotlib.pyplot as plt
import numpy as np


x_1 = np.linspace(-10,10,100)
x_2 = np.linspace(-10,10,100)
(X_1, X_2) = np.meshgrid(x_1, x_2)
f = X_1**2 - X_2**2
g = - X_1**2 + X_2**2
h =  X_1**2 + X_2**2 + X_1*X_2
i =   X_1**2 + X_2**2 - X_1*X_2

fig, ax = plt.subplots(2, 2, figsize=(15, 15))
cs1 = ax[0,0].contour(X_1, X_2, f, levels=6, alpha=0.7, colors="black")
ax[0,0].clabel(cs1, inline=True, fontsize=10)
ax[0,0].set_title("Curvas de nivel de $f_1(x_1, x_2)$")
ax[0,0].set_xlabel("X label")
ax[0,0].set_ylabel("Y label")


cs2 = ax[0, 1].contour(X_1, X_2, g, levels=6, alpha=0.7, colors="black")
ax[0,1].clabel(cs2, inline=True, fontsize=10)
ax[0,1].set_title("Curvas de nivel de $f_2(x_1, x_2)$")
ax[0,1].set_xlabel("X label")
ax[0,1].set_ylabel("Y label")


cs3 = ax[1, 0].contour(X_1, X_2, h, levels=6, alpha=0.7, colors="black")
ax[1,0].clabel(cs3, inline=True, fontsize=10)
ax[1,0].set_title("Curvas de nivel de $f_3(x_1, x_2)$")
ax[1,0].set_xlabel("X label")
ax[1,0].set_ylabel("Y label")


cs4 = ax[1,1].contour(X_1, X_2, i, levels=6, alpha=0.7, colors="black")
ax[1,1].clabel(cs4, inline=True, fontsize=10)
ax[1,1].set_title("Curvas de nivel de $f_4(x_1, x_2)$")
ax[1,1].set_xlabel("X label")
ax[1,1].set_ylabel("Y label")

plt.suptitle("Curvas de nivel O contorno de funciones cuadráticas")


plt.tight_layout()

plt.show()

# %% [markdown]
# **2.3.3.** Grafique en cuatro subplots en una misma figura el mapa de calor de las funciones anteriores. Incluya labels, títulos y título general, así como barra de color. Incluya 12 niveles.

# %%
import matplotlib.pyplot as plt
import numpy as np


x_1 = np.linspace(-10,10,100)
x_2 = np.linspace(-10,10,100)
(X_1, X_2) = np.meshgrid(x_1, x_2)
f = X_1**2 - X_2**2
g = - X_1**2 + X_2**2
h =  X_1**2 + X_2**2 + X_1*X_2
i =   X_1**2 + X_2**2 - X_1*X_2

fig, ax = plt.subplots(2, 2, figsize=(12, 12))


CS1 = ax[0, 0].contourf(X_1, X_2, f, levels=12)
ax[0,0].set_title("Contorno de $f_1(x_1, x_2)$")
ax[0,0].set_xlabel("X label")
ax[0,0].set_ylabel("Y label")
fig.colorbar(CS1, ax=ax[0, 0], label="Valor de $f_1$")

CS2 = ax[0, 1].contourf(X_1, X_2, g, levels=12)
ax[0,1].set_title("Contorno de $f_2(x_1, x_2)$")
ax[0,1].set_xlabel("X label")
ax[0,1].set_ylabel("Y label")

fig.colorbar(CS2, ax=ax[0, 1], label="Valor de $f_2$")


CS3 = ax[1, 0].contourf(X_1, X_2, h, levels=12)
ax[1, 0].set_title("Contorno de $f_3(x_1, x_2)$")
ax[1,0].set_xlabel("X label")
ax[1,0].set_ylabel("Y label")
fig.colorbar(CS3, ax=ax[1, 0], label="Valor de $f_3$")


CS4 = ax[1, 1].contourf(X_1, X_2, i, levels=12)
ax[1,1].set_title("Contorno de $f_4(x_1, x_2)$")
ax[1,1].set_xlabel("X label")
ax[1,1].set_ylabel("Y label")
fig.colorbar(CS4, ax=ax[1, 1], label="Valor de $f_4$")


plt.suptitle("Contornos de funciones cuadráticas")


plt.tight_layout()

plt.show()
